# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('./data/행정안전부_지역별(행정동)_성별_연령별_주민등록_인구수_20240930.csv', encoding = 'cp949')
data
# Out:
#           행정기관코드        기준연월      시도명 시군구명   읍면동명      계    남자    여자  0세남자  \
# 0     1111051500  2024-09-30    서울특별시  종로구  청운효자동  11143  5079  6064    25
# 1     1111053000  2024-09-30    서울특별시  종로구    사직동   8995  3948  5047     8
# 2     1111054000  2024-09-30    서울특별시  종로구    삼청동   2234  1073  1161     1
# 3     1111055000  2024-09-30    서울특별시  종로구    부암동   9054  4255  4799    14
# 4     1111056000  2024-09-30    서울특별시  종로구    평창동  17232  7987  9245    27
# ...          ...         ...      ...  ...    ...    ...   ...   ...   ...
# 3609  5280038000  2024-09-30  전북특별자치도  부안군    백산면   2336  1163  1173     4
# 3610  5280039000  2024-09-30  전북특별자치도  부안군    상서면   2047  1021  1026     0
# 3611  5280040000  2024-09-30  전북특별자치도  부안군    하서면   2374  1174  1200     1
# 3612  5280041000  2024-09-30  전북특별자치도  부안군    줄포면   2430  1203  1227     1
# 3613  5280042000  2024-09-30  전북특별자치도  부안군    위도면   1090   605   485     0
#
# ...

# %% [markdown]
# 0~9
# 10~19
# 20~29
# 30~39
# 40~49
# 50~59
# 60~~

# %%
data['행정기관코드'].dtype
# Out:
# dtype('int64')

# %%
data['행정기관코드'] = data['행정기관코드'].astype(str)

# %%
data['행정기관코드'].dtype
# Out:
# dtype('O')

# %%
# '행정기관코드'의 앞 2자리가 '41'인 것만 남기고 data에 덮어쓰기
data = data[data['행정기관코드'].str.startswith('41')]

# 결과 확인
data
# Out:
#           행정기관코드        기준연월  시도명     시군구명  읍면동명      계     남자     여자  0세남자  \
# 1200  4111156000  2024-09-30  경기도  수원시 장안구   파장동  24855  12547  12308    70
# 1201  4111156600  2024-09-30  경기도  수원시 장안구   율천동  40038  21219  18819    97
# 1202  4111157100  2024-09-30  경기도  수원시 장안구  정자1동  33382  16341  17041    81
# 1203  4111157200  2024-09-30  경기도  수원시 장안구  정자2동  38503  18857  19646   105
# 1204  4111157300  2024-09-30  경기도  수원시 장안구  정자3동  39054  19531  19523    64
# ...          ...         ...  ...      ...   ...    ...    ...    ...   ...
# 1798  4183037000  2024-09-30  경기도      양평군   청운면   3748   1938   1810     2
# 1799  4183038000  2024-09-30  경기도      양평군   양동면   4518   2286   2232     2
# 1800  4183039500  2024-09-30  경기도      양평군   지평면   6688   3411   3277     3
# 1801  4183040000  2024-09-30  경기도      양평군   용문면  18720   9414   9306    21
# 1802  4183041000  2024-09-30  경기도      양평군   개군면   5100   2606   2494     3
#
# ...

# %%
data['행정기관코드'] = data['행정기관코드'].astype(np.int64)

# %%
data['행정기관코드'].dtype
# Out:
# dtype('int64')

# %%
data.columns
# Out:
# Index(['행정기관코드', '기준연월', '시도명', '시군구명', '읍면동명', '계', '남자', '여자', '0세남자',
#        '1세남자',
#        ...
#        '101세여자', '102세여자', '103세여자', '104세여자', '105세여자', '106세여자', '107세여자',
#        '108세여자', '109세여자', '110세이상 여자'],
#       dtype='object', length=230)

# %%
for age in range(60, 111):
    column_name = f"'{age}세여자'"
    # 원하는 작업 수행
    print(column_name, end=", ")
# Out:
# '60세여자', '61세여자', '62세여자', '63세여자', '64세여자', '65세여자', '66세여자', '67세여자', '68세여자', '69세여자', '70세여자', '71세여자', '72세여자', '73세여자', '74세여자', '75세여자', '76세여자', '77세여자', '78세여자', '79세여자', '80세여자', '81세여자', '82세여자', '83세여자', '84세여자', '85세여자', '86세여자', '87세여자', '88세여자', '89세여자', '90세여자', '91세여자', '92세여자', '93세여자', '94세여자', '95세여자', '96세여자', '97세여자', '98세여자', '99세여자', '100세여자', '101세여자', '102세여자', '103세여자', '104세여자', '105세여자', '106세여자', '107세여자', '108세여자', '109세여자', '110세여자',

# %%
data['10세이하남자'] = data[[f"{age}세남자" for age in range(1, 11)]].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\64682101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['10세이하남자'] = data[[f"{age}세남자" for age in range(1, 11)]].sum(axis=1)

# %%
data['10대남자'] = data[[f"{age}세남자" for age in range(10, 20)]].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\1049884756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['10대남자'] = data[[f"{age}세남자" for age in range(10, 20)]].sum(axis=1)

# %%
data['20대남자'] = data[[f"{age}세남자" for age in range(20, 30)]].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\154094490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['20대남자'] = data[[f"{age}세남자" for age in range(20, 30)]].sum(axis=1)

# %%
data['30대남자'] = data[[f"{age}세남자" for age in range(30, 40)]].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\600343920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['30대남자'] = data[[f"{age}세남자" for age in range(30, 40)]].sum(axis=1)

# %%
data['40대남자'] = data[[f"{age}세남자" for age in range(40, 50)]].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\1018439886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['40대남자'] = data[[f"{age}세남자" for age in range(40, 50)]].sum(axis=1)

# %%
data['50대남자'] = data[[f"{age}세남자" for age in range(50, 60)]].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\1937120884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['50대남자'] = data[[f"{age}세남자" for age in range(50, 60)]].sum(axis=1)

# %%
data['60대이상남자'] = data[[f"{age}세남자" for age in range(60, 110)] + ['110세이상 남자']].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\1305130347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['60대이상남자'] = data[[f"{age}세남자" for age in range(60, 110)] + ['110세이상 남자']].sum(axis=1)

# %%
data
# Out:
#           행정기관코드        기준연월  시도명     시군구명  읍면동명      계     남자     여자  0세남자  \
# 1200  4111156000  2024-09-30  경기도  수원시 장안구   파장동  24855  12547  12308    70
# 1201  4111156600  2024-09-30  경기도  수원시 장안구   율천동  40038  21219  18819    97
# 1202  4111157100  2024-09-30  경기도  수원시 장안구  정자1동  33382  16341  17041    81
# 1203  4111157200  2024-09-30  경기도  수원시 장안구  정자2동  38503  18857  19646   105
# 1204  4111157300  2024-09-30  경기도  수원시 장안구  정자3동  39054  19531  19523    64
# ...          ...         ...  ...      ...   ...    ...    ...    ...   ...
# 1798  4183037000  2024-09-30  경기도      양평군   청운면   3748   1938   1810     2
# 1799  4183038000  2024-09-30  경기도      양평군   양동면   4518   2286   2232     2
# 1800  4183039500  2024-09-30  경기도      양평군   지평면   6688   3411   3277     3
# 1801  4183040000  2024-09-30  경기도      양평군   용문면  18720   9414   9306    21
# 1802  4183041000  2024-09-30  경기도      양평군   개군면   5100   2606   2494     3
#
# ...

# %%
data['10세이하여자'] = data[[f"{age}세여자" for age in range(1, 11)]].sum(axis=1)
data['10대여자'] = data[[f"{age}세여자" for age in range(10, 20)]].sum(axis=1)
data['20대여자'] = data[[f"{age}세여자" for age in range(20, 30)]].sum(axis=1)
data['30대여자'] = data[[f"{age}세여자" for age in range(30, 40)]].sum(axis=1)
data['40대여자'] = data[[f"{age}세여자" for age in range(40, 50)]].sum(axis=1)
data['50대여자'] = data[[f"{age}세여자" for age in range(50, 60)]].sum(axis=1)
data['60대이상여자'] = data[[f"{age}세여자" for age in range(60, 110)] + ['110세이상 여자']].sum(axis=1)
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\1232857096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['10세이하여자'] = data[[f"{age}세여자" for age in range(1, 11)]].sum(axis=1)
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\1232857096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['10대여자'] = data[[f"{age}세여자" for age in range(10, 20)]].sum(axis=1)
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17948\1232857096.py:3: SettingWithCopyWarning:
# ...

# %%
data
# Out:
#           행정기관코드        기준연월  시도명     시군구명  읍면동명      계     남자     여자  0세남자  \
# 1200  4111156000  2024-09-30  경기도  수원시 장안구   파장동  24855  12547  12308    70
# 1201  4111156600  2024-09-30  경기도  수원시 장안구   율천동  40038  21219  18819    97
# 1202  4111157100  2024-09-30  경기도  수원시 장안구  정자1동  33382  16341  17041    81
# 1203  4111157200  2024-09-30  경기도  수원시 장안구  정자2동  38503  18857  19646   105
# 1204  4111157300  2024-09-30  경기도  수원시 장안구  정자3동  39054  19531  19523    64
# ...          ...         ...  ...      ...   ...    ...    ...    ...   ...
# 1798  4183037000  2024-09-30  경기도      양평군   청운면   3748   1938   1810     2
# 1799  4183038000  2024-09-30  경기도      양평군   양동면   4518   2286   2232     2
# 1800  4183039500  2024-09-30  경기도      양평군   지평면   6688   3411   3277     3
# 1801  4183040000  2024-09-30  경기도      양평군   용문면  18720   9414   9306    21
# 1802  4183041000  2024-09-30  경기도      양평군   개군면   5100   2606   2494     3
#
# ...

# %%
data.columns
# Out:
# Index(['행정기관코드', '기준연월', '시도명', '시군구명', '읍면동명', '계', '남자', '여자', '0세남자',
#        '1세남자',
#        ...
#        '40대남자', '50대남자', '60대이상남자', '10세이하여자', '10대여자', '20대여자', '30대여자',
#        '40대여자', '50대여자', '60대이상여자'],
#       dtype='object', length=244)

# %%
# 전체 컬럼 이름을 리스트로 출력
print(data.columns.tolist())
# Out:
# ['행정기관코드', '기준연월', '시도명', '시군구명', '읍면동명', '계', '남자', '여자', '0세남자', '1세남자', '2세남자', '3세남자', '4세남자', '5세남자', '6세남자', '7세남자', '8세남자', '9세남자', '10세남자', '11세남자', '12세남자', '13세남자', '14세남자', '15세남자', '16세남자', '17세남자', '18세남자', '19세남자', '20세남자', '21세남자', '22세남자', '23세남자', '24세남자', '25세남자', '26세남자', '27세남자', '28세남자', '29세남자', '30세남자', '31세남자', '32세남자', '33세남자', '34세남자', '35세남자', '36세남자', '37세남자', '38세남자', '39세남자', '40세남자', '41세남자', '42세남자', '43세남자', '44세남자', '45세남자', '46세남자', '47세남자', '48세남자', '49세남자', '50세남자', '51세남자', '52세남자', '53세남자', '54세남자', '55세남자', '56세남자', '57세남자', '58세남자', '59세남자', '60세남자', '61세남자', '62세남자', '63세남자', '64세남자', '65세남자', '66세남자', '67세남자', '68세남자', '69세남자', '70세남자', '71세남자', '72세남자', '73세남자', '74세남자', '75세남자', '76세남자', '77세남자', '78세남자', '79세남자', '80세남자', '81세남자', '82세남자', '83세남자', '84세남자', '85세남자', '86세남자', '87세남자', '88세남자', '89세남자', '90세남자', '91세남자', '92세남자', '93세남자', '94세남자', '95세남자', '96세남자', '97세남자', '98세남자', '99세남자', '100세남자', '101세남자', '102세남자', '103세남자', '104세남자',
# ...

# %%
#
#       10세이하남자  10대남자  ...  40대남자  50대남자  60대이상남자  10세이하여자  10대여자  20대여자  \
# ...

# %%
data = data.drop(['시도명'], axis=1)

# %%
data['기준연월'] = pd.to_datetime(data['기준연월'], format='%Y-%m-%d').dt.to_period('M')

# %%
data['통합주소'] = data['시군구명'] + " " + data['읍면동명']
data
# Out:
#           행정기관코드     기준연월     시군구명  읍면동명      계     남자     여자  10세이하남자  10대남자  \
# 1200  4111156000  2024-09  수원시 장안구   파장동  24855  12547  12308      716    918
# 1201  4111156600  2024-09  수원시 장안구   율천동  40038  21219  18819     1112   1812
# 1202  4111157100  2024-09  수원시 장안구  정자1동  33382  16341  17041     1291   1864
# 1203  4111157200  2024-09  수원시 장안구  정자2동  38503  18857  19646     1561   2009
# 1204  4111157300  2024-09  수원시 장안구  정자3동  39054  19531  19523     1323   2968
# ...          ...      ...      ...   ...    ...    ...    ...      ...    ...
# 1798  4183037000  2024-09      양평군   청운면   3748   1938   1810       44     73
# 1799  4183038000  2024-09      양평군   양동면   4518   2286   2232       64    101
# 1800  4183039500  2024-09      양평군   지평면   6688   3411   3277      101    183
# 1801  4183040000  2024-09      양평군   용문면  18720   9414   9306      534    940
# 1802  4183041000  2024-09      양평군   개군면   5100   2606   2494       82    143
#
# ...

# %%
data.columns
# Out:
# Index(['행정기관코드', '기준연월', '시군구명', '읍면동명', '계', '남자', '여자', '10세이하남자', '10대남자',
#        '20대남자', '30대남자', '40대남자', '50대남자', '60대이상남자', '10세이하여자', '10대여자',
#        '20대여자', '30대여자', '40대여자', '50대여자', '60대이상여자', '통합주소'],
#       dtype='object')

# %%
data = data[['행정기관코드', '기준연월', '시군구명', '읍면동명', '통합주소', '계', '남자', '여자', '10세이하남자', '10대남자',
             '20대남자', '30대남자', '40대남자', '50대남자', '60대이상남자', '10세이하여자', '10대여자',
             '20대여자', '30대여자', '40대여자', '50대여자', '60대이상여자']]

# %%
data
# Out:
#           행정기관코드     기준연월     시군구명  읍면동명          통합주소      계     남자     여자  \
# 1200  4111156000  2024-09  수원시 장안구   파장동   수원시 장안구 파장동  24855  12547  12308
# 1201  4111156600  2024-09  수원시 장안구   율천동   수원시 장안구 율천동  40038  21219  18819
# 1202  4111157100  2024-09  수원시 장안구  정자1동  수원시 장안구 정자1동  33382  16341  17041
# 1203  4111157200  2024-09  수원시 장안구  정자2동  수원시 장안구 정자2동  38503  18857  19646
# 1204  4111157300  2024-09  수원시 장안구  정자3동  수원시 장안구 정자3동  39054  19531  19523
# ...          ...      ...      ...   ...           ...    ...    ...    ...
# 1798  4183037000  2024-09      양평군   청운면       양평군 청운면   3748   1938   1810
# 1799  4183038000  2024-09      양평군   양동면       양평군 양동면   4518   2286   2232
# 1800  4183039500  2024-09      양평군   지평면       양평군 지평면   6688   3411   3277
# 1801  4183040000  2024-09      양평군   용문면       양평군 용문면  18720   9414   9306
# 1802  4183041000  2024-09      양평군   개군면       양평군 개군면   5100   2606   2494
#
# ...

# %%
df = pd.DataFrame(data)

# %%
# 저장할 경로 수정
output_dir = "C:/fintech_service/Project/data/전처리"
output_file = "성별_연령별_주민등록_인구수_전처리.csv"

# 폴더가 존재하지 않으면 생성
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 데이터프레임을 CSV 파일로 저장
df.to_csv(os.path.join(output_dir, output_file), index=False, encoding="utf-8-sig")
